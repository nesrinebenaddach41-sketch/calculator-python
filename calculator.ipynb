# %%
class calculator :   
    def __init__(self):
        self.operations = {
             '+': self.add, 
             '-': self.subtract, 
             '*': self.multiply,
               '/': self.divide }
        
def add(self, x, y):
    return x + y
def subtract (self,x,y):
    return x-y
def multiply(self, x, y): 
    return x * y
def devide (self, x,y)
    if y == 0:
        raise ValueError("Error: Division by zero")
    return x/y 

def add_operation (self , symbol , func):  #pour ajouter une nouvelle operation 
    self.operations=[symbol]=func

def exponentiation(x, y): #fct exponentiation 
    return x ** y

def square_root(x):
     if x < 0: 
        raise ValueError("Error: Cannot take square root of negative number")
        return math.sqrt(x)
     #fct square root 

def logarithm(x):
     if x <= 0:
         raise ValueError("Error: Logarithm only defined for positive numbers")
         return math.log(x)
